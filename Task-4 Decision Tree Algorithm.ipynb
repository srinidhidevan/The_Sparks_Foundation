# %% [markdown]
# # TASK-4: DECISION TREE ALGORITHM

# %% [markdown]
# ### ~ SRINIDHI DEVAN

# %% [markdown]
# ### For the given ‘Iris’ dataset, in this task, we shall create the Decision Tree classifier and visualize it graphically.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Iris.csv')
data = data.drop(['Id'],axis=1)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = data['Species']

# %%
(x_train, x_test, y_train, y_test) = train_test_split(x, y, train_size=0.8, random_state=1)

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini' )

# %%
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_model.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)

# %%
pred = dt_model.predict(x_test)

# %%
fig = plt.figure(figsize=(20,15))
fig = tree.plot_tree(dt_model,feature_names=data.columns,filled='True')
